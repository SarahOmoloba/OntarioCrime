# %%
import pandas as pd
pd.set_option('display.max_columns', 100)

import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('ReducedCrime2008Cleaned.csv')
df.head()
# Out:
#    Year           GEO        DGUID              ViolationType  \
# 0  2008  Ontario [35]  2016A000235  Total, all violations [0]
# 1  2008  Ontario [35]  2016A000235  Total, all violations [0]
# 2  2008  Ontario [35]  2016A000235  Total, all violations [0]
# 3  2008  Ontario [35]  2016A000235  Total, all violations [0]
# 4  2008  Ontario [35]  2016A000235  Total, all violations [0]
#
#                StatDescription UnitOfMeasurement  UOM_ID SCALAR_FACTOR  \
# 0             Actual incidents            Number     223         units
# 1  Rate per 100,000 population              Rate     257         units
# 2    Percentage change in rate           Percent     239         units
# 3                Total cleared            Number     223         units
# 4            Cleared by charge            Number     223         units
#
#    SCALAR_ID     VECTOR COORDINATE      VALUE  DECIMALS
# 0          0  v68753402      1.1.1  705715.00         0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28008348 entries, 0 to 28008347
# Data columns (total 13 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Year               int64
#  1   GEO                object
#  2   DGUID              object
#  3   ViolationType      object
#  4   StatDescription    object
#  5   UnitOfMeasurement  object
#  6   UOM_ID             int64
#  7   SCALAR_FACTOR      object
#  8   SCALAR_ID          int64
#  9   VECTOR             object
#  10  COORDINATE         object
#  11  VALUE              float64
#  12  DECIMALS           int64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 2.7+ GB

# %%
df = df[df.Year >= 2016]
df
# Out:
#           Year                                               GEO  \
# 14871652  2016                                      Ontario [35]
# 14871653  2016                                      Ontario [35]
# 14871654  2016                                      Ontario [35]
# 14871655  2016                                      Ontario [35]
# 14871656  2016                                      Ontario [35]
# ...        ...                                               ...
# 28008343  2021  Canadian Pacific Railway Police, Ontario [35991]
# 28008344  2021  Canadian Pacific Railway Police, Ontario [35991]
# 28008345  2021  Canadian Pacific Railway Police, Ontario [35991]
# 28008346  2021  Canadian Pacific Railway Police, Ontario [35991]
# 28008347  2021  Canadian Pacific Railway Police, Ontario [35991]
#
#                    DGUID                  ViolationType  \
# 14871652     2016A000235      Total, all violations [0]
# 14871653     2016A000235      Total, all violations [0]
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# Display unique values of 'basement'
df.UnitOfMeasurement.unique()
# Out:
# array(['Number', 'Rate', 'Percent'], dtype=object)

# %%
columns_to_drop= ['SCALAR_ID']
df = df.drop(columns_to_drop, axis=1)

# %%
df.head()
# Out:
#           Year           GEO        DGUID              ViolationType  \
# 14871652  2016  Ontario [35]  2016A000235  Total, all violations [0]
# 14871653  2016  Ontario [35]  2016A000235  Total, all violations [0]
# 14871654  2016  Ontario [35]  2016A000235  Total, all violations [0]
# 14871655  2016  Ontario [35]  2016A000235  Total, all violations [0]
# 14871656  2016  Ontario [35]  2016A000235  Total, all violations [0]
#
#                       StatDescription UnitOfMeasurement  UOM_ID SCALAR_FACTOR  \
# 14871652             Actual incidents            Number     223         units
# 14871653  Rate per 100,000 population              Rate     257         units
# 14871654    Percentage change in rate           Percent     239         units
# 14871655          Unfounded incidents            Number     223         units
# 14871656            Percent unfounded           Percent     239         units
#
#                VECTOR COORDINATE      VALUE  DECIMALS
# ...

# %%
df.VALUE.fillna(0.00, inplace=True)

# %%
df.head()
# Out:
#           Year           GEO        DGUID              ViolationType  \
# 14871652  2016  Ontario [35]  2016A000235  Total, all violations [0]
# 14871653  2016  Ontario [35]  2016A000235  Total, all violations [0]
# 14871654  2016  Ontario [35]  2016A000235  Total, all violations [0]
# 14871655  2016  Ontario [35]  2016A000235  Total, all violations [0]
# 14871656  2016  Ontario [35]  2016A000235  Total, all violations [0]
#
#                       StatDescription UnitOfMeasurement  UOM_ID SCALAR_FACTOR  \
# 14871652             Actual incidents            Number     223         units
# 14871653  Rate per 100,000 population              Rate     257         units
# 14871654    Percentage change in rate           Percent     239         units
# 14871655          Unfounded incidents            Number     223         units
# 14871656            Percent unfounded           Percent     239         units
#
#                VECTOR COORDINATE      VALUE  DECIMALS
# ...

# %%
df= df.rename(columns={'REF_DATE': 'Year', 'Violations': 'ViolationName', 'SCALAR_FACTOR': 'UnitOfMeasurement', 'Statistics': 'StatDescription'})

# %%
df= df.rename(columns={'UnitOfMeasurement': 'SCALAR_FACTOR','UOM': 'UnitOfMeasurement'})

# %%
df.to_csv('ReducedCrime2016Cleaned.csv', index=False)
