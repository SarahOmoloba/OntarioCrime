# %%
import pandas as pd
pd.set_option('display.max_columns', 100)

import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('cleaned_data_35100062.csv')
df.head()
# Out:
#    Year                               GEO           DGUID  \
# 0  2016  Canada, selected police services  2016A000011124
# 1  2016  Canada, selected police services  2016A000011124
# 2  2016  Canada, selected police services  2016A000011124
# 3  2016  Canada, selected police services  2016A000011124
# 4  2016  Canada, selected police services  2016A000011124
#
#                                        ViolationName     UOM  UOM_ID  \
# 0                              Total, all violations  Number     223
# 1                                          Homicide   Number     223
# 2       Attempted murder / Conspire to commit murder  Number     223
# 3                                            Assault  Number     223
# 4  Sexual violations (not including against child...  Number     223
#
#   SCALAR_FACTOR       VECTOR  COORDINATE  VALUE
# 0         units  v1066366742        1.78   4810
# 1         units  v1066363814        1.10    119
# 2         units  v1066363815        1.20     44
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 468 entries, 0 to 467
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   REF_DATE                468 non-null    int64
#  1   GEO                     468 non-null    object
#  2   DGUID                   468 non-null    object
#  3   Most serious violation  468 non-null    object
#  4   UOM                     468 non-null    object
#  5   UOM_ID                  468 non-null    int64
#  6   SCALAR_FACTOR           468 non-null    object
#  7   SCALAR_ID               468 non-null    int64
#  8   VECTOR                  468 non-null    object
#  9   COORDINATE              468 non-null    float64
#  10  VALUE                   468 non-null    int64
#  11  STATUS                  0 non-null      float64
#  12  SYMBOL                  0 non-null      float64
#  13  TERMINATED              0 non-null      float64
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# Display unique values of 'basement'
df.REF_DATE.unique()
# Out:
# array([2016, 2017, 2018, 2019, 2020, 2021], dtype=int64)

# %%
df= df.rename(columns={'REF_DATE': 'Year', 'Most serious violation': 'ViolationName'})

# %%
df= df.rename(columns={'UOM': 'UnitOfMeasurement'})

# %%
df.head()
# Out:
#    Year                               GEO           DGUID  \
# 0  2016  Canada, selected police services  2016A000011124
# 1  2016  Canada, selected police services  2016A000011124
# 2  2016  Canada, selected police services  2016A000011124
# 3  2016  Canada, selected police services  2016A000011124
# 4  2016  Canada, selected police services  2016A000011124
#
#                                        ViolationName UnitOfMeasurement  \
# 0                              Total, all violations            Number
# 1                                          Homicide             Number
# 2       Attempted murder / Conspire to commit murder            Number
# 3                                            Assault            Number
# 4  Sexual violations (not including against child...            Number
#
#    UOM_ID SCALAR_FACTOR       VECTOR  COORDINATE  VALUE
# 0     223         units  v1066366742        1.78   4810
# 1     223         units  v1066363814        1.10    119
# ...

# %%
columns_to_drop= ['STATUS','SYMBOL','TERMINATED','DECIMALS','SCALAR_ID']
df = df.drop(columns_to_drop, axis=1)

# %%
df.head()
# Out:
#    Year                               GEO           DGUID  \
# 0  2016  Canada, selected police services  2016A000011124
# 1  2016  Canada, selected police services  2016A000011124
# 2  2016  Canada, selected police services  2016A000011124
# 3  2016  Canada, selected police services  2016A000011124
# 4  2016  Canada, selected police services  2016A000011124
#
#                                        ViolationName     UOM  UOM_ID  \
# 0                              Total, all violations  Number     223
# 1                                          Homicide   Number     223
# 2       Attempted murder / Conspire to commit murder  Number     223
# 3                                            Assault  Number     223
# 4  Sexual violations (not including against child...  Number     223
#
#   SCALAR_FACTOR       VECTOR  COORDINATE  VALUE
# 0         units  v1066366742        1.78   4810
# 1         units  v1066363814        1.10    119
# 2         units  v1066363815        1.20     44
# ...

# %%
df.to_csv('cleaned_data_35100062.csv', index=False)
